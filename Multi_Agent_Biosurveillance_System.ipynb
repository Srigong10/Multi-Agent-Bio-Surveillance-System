# %% [markdown]
# **This is the Agent Intensive - Capstone Project            (Kaggle x Google):**
# It contains all the essential code required to run and explore the **Multi-Agent Biosurveillance System**, including demonstrations of the agents.
#
# **Contents:**
#
# 1. **Setup:** Installation and import of required libraries
# 2. **API Key Configuration**
# 3. **Step 1:** Custom tools setup
# 4. **Step 2:** LLM configuration and Sequential Multi-Agent setup
# 5. **Step 3:** Main Orchestrator — ChatBot configuration
# 6. **Step 4:** Session setup
# 7. **Step 5:** Agent observability setup
# 8. **ADK WebUI Integration with Kaggle**
# 9. **Features Summary**
# 10. **Limitations and Future Improvements**
# ---

# %% [markdown]
# ### **Setup: Installation and import of required libraries**

# %%
#Install Google-ADK
# !pip install google-adk
# Out:
# Requirement already satisfied: google-adk in /usr/local/lib/python3.12/dist-packages (1.19.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.21.0)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from google-adk) (8.3.1)
# Requirement already satisfied: fastapi<0.119.0,>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.118.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.128.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (3.6.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.51.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.22.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pyarrow>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.11.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.32.4)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.48.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.12/dist-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2.0.0,>=1.5.1->google-adk) (43.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery-storage>=2.0.0->google-adk) (1.76.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.7.1)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.29.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.33.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1.0.0,>=0.34.0->google-adk) (0.16.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)

# %%
#Import required libraries
from google.adk.agents import Agent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.genai import types
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.agents import Agent, LlmAgent
from google.adk.sessions import InMemorySessionService
from google.adk.sessions import DatabaseSessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from typing import Any, Dict, List
from google.adk.tools import load_memory, preload_memory
from google.adk.memory import InMemoryMemoryService
from google.adk.tools.agent_tool import AgentTool
import requests
from google.adk.plugins.logging_plugin import (LoggingPlugin,)
import asyncio

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ###**API Key Configuration**

# %%
#Setup the Google API Key
import os
import re
from google.colab import userdata

api_key=userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = api_key

#Setup the Serper API Key
serper_api_key=userdata.get('SERPER.DEV_API_KEY')

#Setup NCBI API Key
NCBI_api_key=userdata.get('NCBI_API_KEY')

print("✅ API keys setup complete.")
# Out:
# ✅ API keys setup complete.

# %%
#Configure Retry Options
#When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# ### **Step 1: Custom Tools Setup**

# %%
# 1. RAW NEWS COLLECTION
def get_disease_outbreak_news(query: str, num_results: int = 5) -> List[Dict[str, str]]:
    """
    Fetch news from Serper.dev News API.
    This function has an ADK-safe signature: only primitive input args.
    """

    api_key = serper_api_key

    url = "https://google.serper.dev/news"
    headers = {"X-API-KEY": api_key}
    payload = {"q": query}

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print(f"News fetch failed ({response.status_code}): {response.text}")
        return []

    data = response.json()

    articles = data.get("news", [])[:num_results]

    return [
        {
            "title":   item.get("title"),
            "link":    item.get("link"),
            "snippet": item.get("snippet"),
            "source":  item.get("source"),
        }
        for item in articles
    ]

# 2. FILTERED OUTBREAK NEWS FUNCTION
def disease_outbreak_news(query: str) -> List[Dict[str, str]]:
    """
    Fetch current microbial or viral outbreak news using the Serper News API.
    Applies filtering for emerging infectious disease–related content.

    Returns:
        List[Dict[str, str]]
    """

    raw_news = get_disease_outbreak_news(query)

    outbreak_keywords = [
        "virus", "bacteria", "fungus", "fungal",
        "prion", "parasite",
        "outbreak", "cluster", "disease",
        "epidemic", "pandemic",
        "infection", "infectious", "news",
        "pathogen", "case count",
    ]

    filtered = []
    for item in raw_news:
        text = f"{item['title']} {item['snippet']}".lower()

        if any(keyword in text for keyword in outbreak_keywords):
            filtered.append(item)

    return filtered

print("✅ The `get_disease_outbreak_news` and `disease_outbreak_news` tools are created.")
# Out:
# ✅ The `get_disease_outbreak_news` and `disease_outbreak_news` tools are created.

# %%
#1. RESEARCH PAPERS COLLECTION AND FILTERING
def fetch_pubmed_papers(query: str, max_results: int = 20) -> List[Dict[str, Any]]:
    """
    Fetch research papers from PubMed.
    Applies filtering for infectious disease–related content.
    """

    api_key = NCBI_api_key

    search_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    search_params = {
        "db": "pubmed",
        "term": query,
        "retmax": max_results,
        "api_key": api_key,
        "retmode": "json"
    }

    search_response = requests.get(search_url, params=search_params)
    ids = search_response.json().get("esearchresult", {}).get("idlist", [])
    if not ids:
        return []

    fetch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    fetch_params = {
        "db": "pubmed",
        "id": ",".join(ids),
        "retmode": "xml",
        "api_key": api_key
    }
    fetch_response = requests.get(fetch_url, params=fetch_params)

    from bs4 import BeautifulSoup
    soup = BeautifulSoup(fetch_response.text, "xml")

    papers = []
    for article in soup.find_all("PubmedArticle"):
        title = article.ArticleTitle.text if article.ArticleTitle else None
        abstract = (
            article.Abstract.AbstractText.text
            if article.Abstract and article.Abstract.AbstractText
            else None
        )
        journal = (
            article.Journal.Title.text
            if article.Journal and article.Journal.Title
            else None
        )

        authors = []
        for author in article.find_all("Author"):
            first = author.ForeName.text if author.ForeName else ""
            last = author.LastName.text if author.LastName else ""
            if first or last:
                authors.append(f"{first} {last}")

        doi_tag = article.find("ArticleId", {"IdType": "doi"})
        doi = doi_tag.text if doi_tag else None

        papers.append(
            {
                "doi": doi,
                "title": title,
                "abstract": abstract,
                "journal": journal,
                "authors": authors,
            }
        )
    return papers

print("✅ The `fetch_pubmed_papers` tool is created.")
# Out:
# ✅ The `fetch_pubmed_papers` tool is created.

# %% [markdown]
# ### **Step 2: LLM configuration and Sequential Multi-Agent setup**

# %%
# NEWS ON INFECTIOUS DISEASES
news_surveillance_agent = LlmAgent(
    name="newssurveillanceagent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the **NEWS Surveillance Analyzer (SP)**.
Your only job is to generate a short, data-driven Surveillance Report using the 'disease_outbreak_news' tool.

---

# OUTPUT FORMAT (MANDATORY — NO EXCEPTIONS)

### 1. Threat Assessment
State the current risk level (LOW / MODERATE / HIGH) and give one short justification.

### 2. Epidemic Trends
Summarize key indicators such as trend direction.
Do not invent values not present in the data.

### 3. Geographic Distribution
List the relevant hotspots or monitored regions based strictly on the provided data.

### 4. References
"references": [
       {
          "title": "...",
          "link": "...",
          "source": "..."
       }
  ]

---

# RULES
- Do not invent data.
- Include ALL article links from the tool output in "references".
- Use ONLY the simulated data given in the prompt.
- Do NOT add, guess, or extrapolate new statistics.
- No external assumptions.
- Keep the report concise, factual, and neutral.

""",

    tools=[disease_outbreak_news, get_disease_outbreak_news]
)

print("✅ Your news_surveillance_agent is created.")
# Out:
# ✅ Your news_surveillance_agent is created.

# %% [markdown]
# *Demonstration of `news_surveillance_agent`:*

# %%
runner = InMemoryRunner(agent=news_surveillance_agent)
response = await runner.run_debug(
    "What is the news on infectious diseases ?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is the news on infectious diseases ?
# newssurveillanceagent > ### 1. Threat Assessment
# MODERATE - Several infectious diseases, including norovirus, E. coli, measles, Marburg virus, and bird flu, are currently active or under investigation globally.
#
# ### 2. Epidemic Trends
# Norovirus cases are rising in the US, and global measles cases surpassed pre-Covid levels in 2024. Bird flu viruses are noted as a significant threat due to their fever resistance.
#
# ### 3. Geographic Distribution
# Hotspots and monitored regions include the US (norovirus, E. coli), Ethiopia (Marburg virus), and global (measles, bird flu).
#
# ### 4. References
# [{"title": "Cases of infectious norovirus are rising across the US this holiday season", "link": "https://www.the-independent.com/news/health/norovirus-cases-us-holiday-infections-b2873219.html", "source": "The Independent"}, {"title": "Notes from the Field: Outbreak of Escherichia coli ...", "link": "https://www.cdc.gov/mmwr/volumes/74/wr/mm7438a2.htm", "source": "Centers for Disease Control and Prevention | CDC (.gov)"}, {"title": "Global measles vaccinations are nearly back to pre-pandemic levels, WHO report finds", "link": "https://www.statnews.com/2025/11/28/measles-who-report-vaccinations-cases/", "source": "STAT"}, {"title": "Ethiopia Investigates Marburg Virus Disease Outbreak", "link": "https://www.contagionlive.com/view/ethiopia-investigates-marburg-virus-disease-outbreak", "source": "Contagion Live"}, {"title": "Fever-resistant bird flu viruses pose a significant threat to humans", "link": "https://www.news-medical.net/news/20251128/Fever-resistant-bird-flu-viruses-pose-a-significant-threat-to-humans.aspx", "source": "News-Medical"}]

# %%
#A. RESEARCH PAPER FINDER
research_paper_finder_agent = LlmAgent(
    name="paperingestion",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config),
    instruction="""
        You are a research paper ingestion agent.
        Use the fetch_pubmed_papers tool whenever the user requests:
        - research papers
        - PubMed articles
        - biomedical literature
        - research work
        - recent research
        Return structured metadata (DOI, title, authors, abstract, journal).
        If full text is requested, explain whether full text is available via PubMed or must be accessed externally.
    """,
    tools=[fetch_pubmed_papers],
    output_key="paper_metadata"
)

print("✅ Your research_paper_finder_agent is created.")
# Out:
# ✅ Your research_paper_finder_agent is created.

# %%
#B. RESEARCH EXTRACTOR
research_extractor_agent = LlmAgent(
    name="researchextractor",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config),
    instruction="""
    Using the output of 'paper_metadata'
    Extract structured fields:
    - DOI
    - pathogen
    - variant
    - virulence_factor
    - gene_or_protein
    - mechanism
    - mutations
    - evidence_strength
    - date
    Format output as JSON list.

    # OUTPUT FORMAT (MANDATORY — NO EXCEPTIONS)
[
  {
    "doi": "...",
    "pathogen": "...",
    "variant": "...",
    "virulence_factor": "...",
    "gene_or_protein": "...",
    "mechanism": "...",
    "mutations": "...",
    "evidence_strength": "...",
    "date": "...",
    "reference": {
         "doi": "..."
    }
  }
]

• Ensure the DOI is always included inside "reference".
    """,
)

print("✅ Your research_extractor_agent is created.")
# Out:
# ✅ Your research_extractor_agent is created.

# %%
#C. BIOSURVEILLANCE
bio_surveillance_agent = SequentialAgent(
    name="biosurveillanceagent",
    sub_agents=[
        research_paper_finder_agent,
        research_extractor_agent,
    ]
)

print("✅ Your bio_surveillance_agent is created.")
# Out:
# ✅ Your bio_surveillance_agent is created.

# %% [markdown]
# *Demonstration of `bio_surveillance_agent`:*

# %%
runner = InMemoryRunner(agent=bio_surveillance_agent)
response = await runner.run_debug(
    "What the research state about Marburg virus disease ?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What the research state about Marburg virus disease ?
# paperingestion > Marburg virus disease (MVD) is a highly virulent pathogen that causes acute hemorrhagic fever outbreaks. Despite its potential to cause explosive outbreaks and pose a threat to public health, MVD remains significantly under-researched, with a notable lack of comprehensive scientific evidence. This limited attention has resulted in gaps in understanding its epidemiology, clinical management, and prevention strategies.
#
# Recent research has focused on several key areas:
#
# *   **Reservoir and Transmission:** Egyptian rousette bats (ERBs) are identified as the natural reservoir for Marburg virus (MARV). Studies are investigating how the virus is maintained within bat populations and the mechanisms behind zoonotic spillover events. Recent outbreaks in regions without prior records, such as Ghana, Tanzania, Equatorial Guinea, and Rwanda, challenge the current understanding of at-risk areas. Surveillance in bats, including in Madagascar, has detected seroreactivity against Marburg viruses, highlighting the need for ongoing biosurveillance.
# *   **Viral Mechanisms and Targets:** Research is exploring viral proteins like VP35 as potential antiviral targets. Computational methods, including molecular docking and simulations, are being used to identify natural compounds that could inhibit VP35 function. Additionally, studies are investigating the formation and transport of nucleocapsids, with a focus on conserved motifs like the PPxPxY motif in NP, as potential targets for antiviral development against both Marburg and Ebola viruses.
# *   **Vaccine Development:** Various vaccine approaches are under investigation, including vector-based vaccines (measles virus, adenovirus, vesicular stomatitis virus), DNA vaccines, virus-like particles, and recombinant proteins. Some studies show promising results in animal models, with certain vaccines conferring protection against lethal challenges. However, challenges remain, such as the lack of cross-protection against multiple filovirus species and the need for improved immunogenicity in human trials. Immunoinformatics is also being explored to accelerate vaccine design.
# *   **Disease Modeling and Preparedness:** There's a recognized need for better disease modeling, particularly in lower-resource settings, to accurately predict disease dynamics and inform public health responses. Challenges include data collection, accounting for socio-cultural determinants, and understanding the complex interplay between disease dynamics and human behavior, especially when facing multiple concurrent outbreaks like Marburg virus and Mpox.
#
# While short human-to-human transmission chains have generally been documented, the increasing occurrence of Marburg virus outbreaks in Africa warrants continued attention and research to better understand and control this potentially devastating disease.
# researchextractor > ```json
# [
#   {
#     "doi": "10.1371/journal.pntd.0013701",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "zoonotic spillover",
#     "mutations": null,
#     "evidence_strength": null,
#     "date": null
#   },
#   {
#     "doi": "10.3389/fimmu.2025.1686343",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "interferon response, cytokine storm signaling",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1186/s42522-025-00178-0",
#     "pathogen": "Marburg virus",
#     "variant": "Ravn virus",
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "zoonotic spillover",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1371/journal.pone.0334160",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": "VP35",
#     "gene_or_protein": "VP35",
#     "mechanism": "inhibition of viral replication, transcription, and nucleocapsid assembly",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1099/jgv.0.002157",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "glycoprotein (GP)",
#     "mechanism": "vaccination",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1007/s13337-025-00940-y",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "zoonotic transmission",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1128/jvi.01018-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "glycoprotein (GP)",
#     "mechanism": "cell entry, host range restriction",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.4314/rjmhs.v8i2.20",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "epidemiology, transmission dynamics, prevention",
#     "mutations": null,
#     "evidence_strength": "moderate",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1128/mbio.01557-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "NP, VP35, VP24, VP30",
#     "mechanism": "nucleocapsid assembly and transport, viral transcription and replication",
#     "mutations": "PPxPxY motif in NP",
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1186/s41256-025-00449-3",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "disease modeling, public health response",
#     "mutations": null,
#     "evidence_strength": "moderate",
#     "date": "2025"
#   },
#   {
#     "doi": "10.3390/ijms26178485",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "NP, VP35, VP24, VP30",
#     "mechanism": "intercellular transport, cell-to-cell spread",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1016/j.bbrc.2025.152572",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "vaccine design",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1111/1751-7915.70225",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "glycoprotein",
#     "mechanism": "zoonotic spillover, human-to-human transmission, antiviral treatment, vaccination",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1016/j.ymthe.2025.08.022",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "glycoproteins",
#     "mechanism": "vaccination, cross-protection",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1128/mbio.02033-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "viral prospecting, vaccine development",
#     "mutations": null,
#     "evidence_strength": "moderate",
#     "date": "2025"
#   },
#   {
#     "doi": "10.1186/s12985-025-02884-7",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "glycoprotein (GP)",
#     "mechanism": "vaccine design, glycosylation",
#     "mutations": null,
#     "evidence_strength": "strong",
#     "date": "2025"
#   }
# ]
# ```

# %%
# AGGREGATION OF THE NEWS AND RESEARCH OUTPUTS
data_aggregator_agent = LlmAgent(
    name="dataaggregatoragent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the Fusion Intelligence Agent.

You will receive:
- news_surveillance_output
- bio_surveillance_output

Your job is to integrate these into a unified analytic snapshot.

────────────────────────────────────────
FUSION TASKS (MANDATORY)
────────────────────────────────────────
1. Aggregate both inputs into a single, concise summary:
    • Key pathogen(s)
    • Relevant mutations or molecular signals
    • Outbreak regions or clusters
    • CRITICAL: Any apparent correlation between surveillance and research literatures

2. Apply the RISK ENGINE (rules below).

────────────────────────────────────────
RISK ENGINE RULES
────────────────────────────────────────
Assign a HIGH / MODERATE / LOW risk score:

- HIGH if:
    • surveillance mentions "rapid spread", "cluster expansion", or
    • molecular evidence includes "increased transmissibility",
      "immune escape", or "high-impact mutation".

- MODERATE if:
    • surveillance reports emerging but contained outbreaks OR
    • literature indicates mutations of uncertain significance.

- LOW if:
    • minimal surveillance signals AND
    • no concerning molecular factors.

────────────────────────────────────────
FUSION REQUIREMENTS
────────────────────────────────────────
1. Create a single concise analytic summary.
2. Apply the Risk Engine.
3. Aggregate ALL references:
    • News article links from surveillance
    • DOIs from molecular papers

────────────────────────────────────────
OUTPUT FORMAT (STRICT)
────────────────────────────────────────
{
  "fusion_summary": "...",
  "risk_level": "HIGH | MODERATE | LOW",
  "justification": "...",
  "references": {
        "news_articles": [
             {"title": "...", "link": "...", "source": "..."}
        ],
        "research_articles": [
             {"doi": "..."}
        ]
  }
}

────────────────────────────────────────
RULES:
• Do not fabricate references.
• Only use references passed by prior agents.
• Keep the summary concise.
""",
)

#THE FUSION PIPELINE
fusion_pipeline = SequentialAgent(
    name="fusion_pipeline",
    sub_agents=[
        news_surveillance_agent,      # existing surveillance agent
        bio_surveillance_agent,    # existing molecular evidence pipeline
        data_aggregator_agent                 # fusion layer
    ]
)


print("✅ Your fusion_pipeline is created.")
# Out:
# ✅ Your fusion_pipeline is created.

# %% [markdown]
# *Demonstration of `fusion_pipeline`:*

# %%
runner = InMemoryRunner(agent=fusion_pipeline)
response = await runner.run_debug(
    "How the latest news and research aligns with Marburg virus disease?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > How the latest news and research aligns with Marburg virus disease?
# newssurveillanceagent > ### 1. Threat Assessment
# MODERATE: Marburg virus disease has an up to 88% fatality ratio, and recent outbreaks in Ethiopia and Rwanda indicate its re-emergence.
#
# ### 2. Epidemic Trends
# The trend indicates a re-emergence of Marburg virus disease, with recent outbreaks reported in Ethiopia and Rwanda. Research is focused on understanding human immune responses to the virus.
#
# ### 3. Geographic Distribution
# Hotspots and monitored regions include Ethiopia and Rwanda.
#
# ### 4. References
# "references": [
#        {
#           "title": "Global Virus Network outlines priorities as Marburg virus emerges in Ethiopia",
#           "link": "https://www.news-medical.net/news/20251127/Global-Virus-Network-outlines-priorities-as-Marburg-virus-emerges-in-Ethiopia.aspx",
#           "source": "News-Medical"
#        },
#        {
#           "title": "Marburg Virus Disease in Rwanda, 2024 — Public Health and Clinical Responses",
#           "link": "https://www.nejm.org/doi/full/10.1056/NEJMoa2415816",
#           "source": "The New England Journal of Medicine"
#        },
#        {
#           "title": "Marburg virus disease",
#           "link": "https://www.who.int/news-room/fact-sheets/detail/marburg-virus-disease",
#           "source": "World Health Organization (WHO)"
#        },
#        {
#           "title": "Groundbreaking study in Rwanda to unlock new insights into Marburg virus immunity",
#           "link": "https://cepi.net/groundbreaking-study-rwanda-unlock-new-insights-marburg-virus-immunity",
#           "source": "CEPI"
#        },
#        {
#           "title": "The next pandemic? New study identifies global hotspots of zoonotic threats",
#           "link": "https://joint-research-centre.ec.europa.eu/jrc-news-and-updates/next-pandemic-new-study-identifies-global-hotspots-zoonotic-threats-2025-07-23_en",
#           "source": "The Joint Research Centre: EU Science Hub"
#        }
#   ]
# paperingestion > The latest news and research show that Marburg virus disease (MVD) is a significant concern due to its high fatality rate (up to 88%) and recent re-emergence in Ethiopia and Rwanda.
#
# Here's a summary of the research and news:
#
# *   **Outbreaks and Surveillance:**
#     *   Recent outbreaks have been reported in Rwanda (2024) and Ethiopia.
#     *   The Global Virus Network is outlining priorities in response to the emergence of MVD in Ethiopia.
#     *   Research is being conducted in Rwanda to understand immunity to the Marburg virus.
#     *   There's a broader study identifying global hotspots of zoonotic threats, indicating that changing climates and human activities can increase disease outbreak risks.
#
# *   **Research Focus:**
#     *   **Vaccine Development:** Multiple studies are exploring vaccine candidates, including:
#         *   Using immunoinformatics to design vaccines targeting the Marburg virus glycoprotein.
#         *   Developing multivalent vaccines against hemorrhagic fevers, including Marburg virus.
#         *   Investigating measles virus-based vaccine candidates for pan-filovirus immunization (protecting against both Ebola and Marburg viruses).
#         *   Comparing the immunogenicity of Marburg virus glycoproteins produced in different cell systems.
#     *   **Antiviral Strategies:** Research is underway to identify potential antiviral targets, such as the viral protein (VP35), and screening for compounds that could inhibit its function.
#     *   **Viral Mechanisms:** Studies are delving into the molecular mechanisms of Marburg virus, including:
#         *   Investigating nucleocapsid assembly and transport within host cells.
#         *   Understanding how bats, as natural reservoirs, manage to control the virus without showing symptoms.
#         *   Comparing the biological properties of different filoviruses, including bat-derived ones.
#     *   **Epidemiology and Transmission:**
#         *   Research is being done to assess exposure to zoonoses and perceptions of transmission risks in areas like Uganda, near potential spillover zones.
#         *   Studies are examining serological evidence of Marburg viruses in bats in Madagascar.
#         *   There's a scoping review exploring the epidemiology, transmission dynamics, and public health interventions for MVD globally, highlighting that the disease remains under-researched.
#
# *   **Risk Assessment:**
#     *   The World Health Organization (WHO) factsheet provides basic information on MVD, noting its high case fatality ratio.
#     *   Some research suggests that while Marburg virus outbreaks have high mortality, the number of cases has been relatively small, with short human-to-human transmission chains. However, continuous genomic analysis for transmission mutants is warranted.
#     *   There is ongoing discussion about the effectiveness of viral prospecting in animals for accelerating vaccine development.
#
# In essence, the recent news and research underscore the ongoing threat posed by Marburg virus disease, with a strong emphasis on developing vaccines and therapeutics, understanding its transmission, and monitoring at-risk populations and regions.
# researchextractor > ```json
# [
#   {
#     "DOI": "10.1371/journal.pntd.0013701",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Zoonotic transmission",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": null
#   },
#   {
#     "DOI": "10.3389/fimmu.2025.1686343",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Interferon response, Cytokine storm signaling",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1186/s42522-025-00178-0",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Zoonotic spillover",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1371/journal.pone.0334160",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": "VP35",
#     "gene_or_protein": "VP35",
#     "mechanism": "Viral replication, Transcription, Nucleocapsid assembly",
#     "mutations": null,
#     "evidence_strength": "Strong",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1099/jgv.0.002157",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Glycoproteins (GPs), Nucleoprotein (NP)",
#     "mechanism": "Vaccination",
#     "mutations": null,
#     "evidence_strength": "Moderate",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1007/s13337-025-00940-y",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Zoonotic origin, Human-to-human transmission",
#     "mutations": null,
#     "evidence_strength": "Strong",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1016/S0140-6736(25)01635-6",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": null,
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1017/S0950268825100563",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": null,
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1128/jvi.01018-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Glycoproteins (GPs)",
#     "mechanism": "Viral entry",
#     "mutations": null,
#     "evidence_strength": "Strong",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1016/j.jacc.2025.08.015",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": null,
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.4314/rjmhs.v8i2.20",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Epidemiology, Transmission dynamics",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": null
#   },
#   {
#     "DOI": "10.1128/mbio.01557-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": "VP35, VP24, VP30",
#     "gene_or_protein": "Nucleocapsid proteins (NP, VP35, VP24, VP30)",
#     "mechanism": "Nucleocapsid assembly, Nucleocapsid transport",
#     "mutations": "PPxPxY motif",
#     "evidence_strength": "Strong",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1186/s41256-025-00449-3",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Zoonotic threat, Disease modeling",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.3390/ijms26178485",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Nucleocapsid-like structures (NCLSs)",
#     "mechanism": "Intercellular transport, Cell-to-cell spread",
#     "mutations": null,
#     "evidence_strength": "Strong",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1016/j.bbrc.2025.152572",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Glycoprotein (GP)",
#     "mechanism": "Vaccine design",
#     "mutations": null,
#     "evidence_strength": "Moderate",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1111/1751-7915.70225",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": "Glycoprotein",
#     "gene_or_protein": "Nucleoprotein NP, Glycoprotein",
#     "mechanism": "Zoonotic spillover, Human-to-human transmission, Antiviral treatment, Vaccine development",
#     "mutations": null,
#     "evidence_strength": "Moderate",
#     "date": null
#   },
#   {
#     "DOI": "10.1016/j.ymthe.2025.08.022",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Glycoproteins",
#     "mechanism": "Vaccination, Pan-filovirus immunization",
#     "mutations": null,
#     "evidence_strength": "Moderate",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1128/mbio.02033-25",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Viral prospecting, Vaccine development",
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1016/j.bbi.2025.106073",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": null,
#     "mutations": null,
#     "evidence_strength": "Unknown",
#     "date": "2025"
#   },
#   {
#     "DOI": "10.1186/s12985-025-02884-7",
#     "pathogen": "Marburg virus",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": "Glycoprotein (GP)",
#     "mechanism": "Vaccine efficacy, Glycosylation",
#     "mutations": null,
#     "evidence_strength": "Moderate",
#     "date": "2025"
#   }
# ]
# ```
# dataaggregatoragent > {
#   "fusion_summary": "Marburg virus disease (MVD) poses a significant public health threat due to its high case fatality ratio (up to 88%), with recent outbreaks reported in Ethiopia and Rwanda. Research is actively pursuing vaccine development through various approaches, including immunoinformatics, multivalent vaccines, and novel vector-based strategies. Investigations into MVD also focus on understanding its molecular mechanisms, such as nucleocapsid assembly and transport, and exploring potential antiviral targets like the VP35 protein. Epidemiological studies are examining zoonotic transmission risks and identifying potential reservoirs, including bats in Madagascar and Uganda, with ongoing efforts to improve disease modeling in affected regions. While MVD outbreaks have generally been contained with short human-to-human transmission chains, continuous genomic analysis for emergent transmission mutants is warranted.",
#   "risk_level": "MODERATE",
#   "justification": "The surveillance literature reports emerging but contained outbreaks in Ethiopia and Rwanda. While research is active in vaccine and antiviral development, no molecular evidence points to increased transmissibility or immune escape mutations, aligning with a MODERATE risk level.",
#   "references": {
#     "news_articles": [
#       {
#         "title": "Global Virus Network outlines priorities as Marburg virus emerges in Ethiopia",
#         "link": "https://www.news-medical.net/news/20251127/Global-Virus-Network-outlines-priorities-as-Marburg-virus-emerges-in-Ethiopia.aspx",
#         "source": "News-Medical"
#       },
#       {
#         "title": "Marburg Virus Disease in Rwanda, 2024 — Public Health and Clinical Responses",
#         "link": "https://www.nejm.org/doi/full/10.1056/NEJMoa2415816",
#         "source": "The New England Journal of Medicine"
#       },
#       {
#         "title": "Marburg virus disease",
#         "link": "https://www.who.int/news-room/fact-sheets/detail/marburg-virus-disease",
#         "source": "World Health Organization (WHO)"
#       },
#       {
#         "title": "Groundbreaking study in Rwanda to unlock new insights into Marburg virus immunity",
#         "link": "https://cepi.net/groundbreaking-study-rwanda-unlock-new-insights-marburg-virus-immunity",
#         "source": "CEPI"
#       },
#       {
#         "title": "The next pandemic? New study identifies global hotspots of zoonotic threats",
#         "link": "https://joint-research-centre.ec.europa.eu/jrc-news-and-updates/next-pandemic-new-study-identifies-global-hotspots-zoonotic-threats-2025-07-23_en",
#         "source": "The Joint Research Centre: EU Science Hub"
#       }
#     ],
#     "research_articles": [
#       {
#         "doi": "10.1371/journal.pntd.0013701"
#       },
#       {
#         "doi": "10.3389/fimmu.2025.1686343"
#       },
#       {
#         "doi": "10.1186/s42522-025-00178-0"
#       },
#       {
#         "doi": "10.1371/journal.pone.0334160"
#       },
#       {
#         "doi": "10.1099/jgv.0.002157"
#       },
#       {
#         "doi": "10.1007/s13337-025-00940-y"
#       },
#       {
#         "doi": "10.1016/S0140-6736(25)01635-6"
#       },
#       {
#         "doi": "10.1017/S0950268825100563"
#       },
#       {
#         "doi": "10.1128/jvi.01018-25"
#       },
#       {
#         "doi": "10.1016/j.jacc.2025.08.015"
#       },
#       {
#         "doi": "10.4314/rjmhs.v8i2.20"
#       },
#       {
#         "doi": "10.1128/mbio.01557-25"
#       },
#       {
#         "doi": "10.1186/s41256-025-00449-3"
#       },
#       {
#         "doi": "10.3390/ijms26178485"
#       },
#       {
#         "doi": "10.1016/j.bbrc.2025.152572"
#       },
#       {
#         "doi": "10.1111/1751-7915.70225"
#       },
#       {
#         "doi": "10.1016/j.ymthe.2025.08.022"
#       },
#       {
#         "doi": "10.1128/mbio.02033-25"
#       },
#       {
#         "doi": "10.1016/j.bbi.2025.106073"
#       },
#       {
#         "doi": "10.1186/s12985-025-02884-7"
#       }
#     ]
#   }
# }

# %% [markdown]
# ### **Step 3: Main Orchestrator — ChatBot configuration**

# %%
# THE MAIN ORCHESTRATOR: THE CHATBOT
root_agent = LlmAgent(
    name="InteractingAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the Pandemic Surveillance & Molecular-Evidence Orchestrator.

Your responsibilities are strictly limited to:
    (1) Providing optional high-level surveillance context on request
    (2) Extracting molecular evidence from scientific literature

────────────────────────────────────────────
SURVEILLANCE REQUEST ROUTING
────────────────────────────────────────────
If the user explicitly asks for:
    • surveillance
    • outbreak signals
    • global monitoring
    • epidemic situation
    • risk level
    • current news
    • latest information

Then you MUST immediately call the tool:
    news_surveillance_agent
and pass the entire user query as the input.

────────────────────────────────────────────
MOLECULAR-EVIDENCE ROUTING
────────────────────────────────────────────
If the user message contains ANY of the following words:
    virulence, virulence factor, mutation, variant,
    gene, protein, genomic, molecular, mechanism,
    sequence, strain, evidence, research,

Then you MUST immediately call the tool:
    bio_surveillance_agent
and pass the entire user query as the input.

────────────────────────────────────────────
FUSION ROUTING
────────────────────────────────────────────
If the user requests BOTH:
    • surveillance context
AND
    • molecular evidence

Then call the tool:
    fusion_pipeline

────────────────────────────────────────────
OUT OF SCOPE
────────────────────────────────────────────
If the query does not involve:
    • surveillance/outbreak context OR
    • molecular evidence

Respond ONLY with:

    "I can only assist with surveillance reports and molecular-evidence analysis."

────────────────────────────────────────────
SAFETY
────────────────────────────────────────────
Never give wet-lab steps, genetic engineering instructions,
experimental workflows, or anything operational.
Only high-level summaries of published literature or simulated data.
""",

    tools=[
        AgentTool(agent=news_surveillance_agent),
        AgentTool(agent=bio_surveillance_agent),
        AgentTool(agent=fusion_pipeline)
    ]
)

print("✅ Your root_agent, the main orchestrator is created.")
# Out:
# ✅ Your root_agent, the main orchestrator is created.

# %% [markdown]
# *Demonstration of `root_agent`:*

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "what is the current news on marburg virus ?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > what is the current news on marburg virus ?
# PandemicPreventingAgent > The current news on Marburg virus indicates a moderate threat, with an increasing trend of cases and deaths reported in Ethiopia. The virus has been detected near the South Sudan border, raising regional alarm and prompting international assistance. At least nine cases and six confirmed deaths have been reported in Ethiopia.

# %% [markdown]
# ####**ISSUE RELATED TO THE MEMORY OF THE MODEL!!**
# ####*The model could not recall the previous question*

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "what was my previous question ?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > what was my previous question ?
# PandemicPreventingAgent > I cannot access your previous questions. I am a stateless model. How can I help you today?

# %% [markdown]
# ### **Step 4: Session setup**

# %%
# Defining helper functions
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
# Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# %%
# Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

# %% [markdown]
# #### **THIS TIME THE MODEL RECALLED AND ANSWERED THE QUESTION**

# %%
await run_session(
    runner,
    [
        "What are the variants of coronavirus?",
        "What was my previous question?",
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > What are the variants of coronavirus?
# gemini-2.5-flash-lite >  The variants of coronavirus (SARS-CoV-2) include JN.1, XBB.1.5, BA.5, Omicron, Gamma, Delta, NB.1.8.1, BA.1, EG.5.1, BA.2.86, KP.2, KP.3, AY.120, and Alpha. The evidence strength for these variants is considered strong, with associated dates ranging from 2021 to 2025.
#
# User > Answer my previous question?
# gemini-2.5-flash-lite >  The variants of coronavirus (SARS-CoV-2) with strong evidence include JN.1, Omicron BA.5, Omicron subvariant XBB.1.5, Gamma, Delta, Omicron, LP.8.1.4, Omicron LP.8.1, XDV.1, NB.1.8.1, Omicron BA.1, Omicron XBB.1.9, B.1.1.7, B.1.1.529, B.1.617.2, Alpha, Pango BA.1.1, Pango BA.1.17, Pango BA.1, EG.5.1, BA.2.86, KP.2, and KP.3.

# %% [markdown]
# ### **Step 5: Agent Observability Setup**

# %%
runner = InMemoryRunner(
    agent=root_agent,
    plugins=[
        LoggingPlugin()
    ],  # Add the plugin. Handles standard Observability logging across ALL agents
)

print("✅ Runner configured")
# Out:
# ✅ Runner configured

# %%
response = await runner.run_debug("Find recent papers on coronavirus")
# Out:
#  ### Created new session: debug_session_id
#
# User > Find recent papers on coronavirus
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-6cc5ce3f-60f5-4edc-9aa5-c076c8f4e967
# [logging_plugin]    Session ID: debug_session_id
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: PandemicPreventingAgent
# [logging_plugin]    User Content: text: 'Find recent papers on coronavirus'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-6cc5ce3f-60f5-4edc-9aa5-c076c8f4e967
# [logging_plugin]    Starting Agent: PandemicPreventingAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: PandemicPreventingAgent
# [logging_plugin]    Invocation ID: e-6cc5ce3f-60f5-4edc-9aa5-c076c8f4e967
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    System Instruction: '
# You are the Pandemic Surveillance & Molecular-Evidence Orchestrator.
#
# Your responsibilities are strictly limited to:
#     (1) Providing optional high-level surveillance context on request
#     (2) Extr...'
# [logging_plugin]    Available Tools: ['newssurveillanceagent', 'biosurveillanceagent', 'fusion_pipeline']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    Content: function_call: biosurveillanceagent
# [logging_plugin]    Token Usage - Input: 513, Output: 20
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5a59aea9-f028-4778-85ae-7da96cee1717
# [logging_plugin]    Author: PandemicPreventingAgent
# [logging_plugin]    Content: function_call: biosurveillanceagent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['biosurveillanceagent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: biosurveillanceagent
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    Function Call ID: adk-e008eaf5-d1ef-4325-98b1-1a14a723ec3b
# [logging_plugin]    Arguments: {'request': 'Find recent papers on coronavirus'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin]    Session ID: 14e4a450-fd62-4355-95fb-3e00fdeedaba
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: biosurveillanceagent
# [logging_plugin]    User Content: text: 'Find recent papers on coronavirus'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin]    Starting Agent: biosurveillanceagent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: biosurveillanceagent
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: paper_ingestion
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    System Instruction: '
#         You are a research paper ingestion agent.
#         Use the fetch_pubmed_papers tool whenever the user requests:
#         - research papers
#         - PubMed articles
#         - biomedical literat...'
# [logging_plugin]    Available Tools: ['fetch_pubmed_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    Content: function_call: fetch_pubmed_papers
# [logging_plugin]    Token Usage - Input: 199, Output: 18
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c18f7d92-6d7f-4960-a44d-515cad20c1dd
# [logging_plugin]    Author: paper_ingestion
# [logging_plugin]    Content: function_call: fetch_pubmed_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['fetch_pubmed_papers']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: fetch_pubmed_papers
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    Function Call ID: adk-8c9a8de4-602c-4442-9ed2-4435a541afc1
# [logging_plugin]    Arguments: {'query': 'recent coronavirus'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: fetch_pubmed_papers
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    Function Call ID: adk-8c9a8de4-602c-4442-9ed2-4435a541afc1
# [logging_plugin]    Result: [{'doi': '10.1097/QCO.0000000000001165', 'title': 'Antiviral clinical trial design throughout the COVID pandemic: evolving endpoints and lessons learnt.', 'abstract': 'Trial design during the novel coronavirus-19 (COVID-19) pandemic was stymied by significant uncertainty about the natural history of...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 52b0f6f9-137d-4b38-98f5-bd06e5d5a8e8
# [logging_plugin]    Author: paper_ingestion
# [logging_plugin]    Content: function_response: fetch_pubmed_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['fetch_pubmed_papers']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    System Instruction: '
#         You are a research paper ingestion agent.
#         Use the fetch_pubmed_papers tool whenever the user requests:
#         - research papers
#         - PubMed articles
#         - biomedical literat...'
# [logging_plugin]    Available Tools: ['fetch_pubmed_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: paper_ingestion
# [logging_plugin]    Content: text: 'Here are some recent papers on coronavirus:
#
# *   **Title:** Antiviral clinical trial design throughout the COVID pandemic: evolving endpoints and lessons learnt.
#     **Authors:** Beatrice Z Sim, Andre...'
# [logging_plugin]    Token Usage - Input: 7407, Output: 7073
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0352b479-f6b3-47c8-bbeb-f00da30c0b43
# [logging_plugin]    Author: paper_ingestion
# [logging_plugin]    Content: text: 'Here are some recent papers on coronavirus:
#
# *   **Title:** Antiviral clinical trial design throughout the COVID pandemic: evolving endpoints and lessons learnt.
#     **Authors:** Beatrice Z Sim, Andre...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: paper_ingestion
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: extraction
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: extraction
# [logging_plugin]    System Instruction: '
#     Using the output of 'paper_metadata'
#     Extract structured fields:
#     - DOI
#     - pathogen
#     - variant
#     - virulence_factor
#     - gene_or_protein
#     - mechanism
#     - mutations
#     - evide...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: extraction
# [logging_plugin]    Content: text: '```json
# [
#   {
#     "DOI": "10.1097/QCO.0000000000001165",
#     "pathogen": "SARS-CoV-2",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Antiviral clini...'
# [logging_plugin]    Token Usage - Input: 14435, Output: 2296
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 660e0def-cbe5-4c83-9e37-be8c813537c4
# [logging_plugin]    Author: extraction
# [logging_plugin]    Content: text: '```json
# [
#   {
#     "DOI": "10.1097/QCO.0000000000001165",
#     "pathogen": "SARS-CoV-2",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Antiviral clini...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: extraction
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: biosurveillanceagent
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-12dbbbce-7464-45a8-a78b-c0a024b33aa0
# [logging_plugin]    Final Agent: biosurveillanceagent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: biosurveillanceagent
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    Function Call ID: adk-e008eaf5-d1ef-4325-98b1-1a14a723ec3b
# [logging_plugin]    Result: ```json
# [
#   {
#     "DOI": "10.1097/QCO.0000000000001165",
#     "pathogen": "SARS-CoV-2",
#     "variant": null,
#     "virulence_factor": null,
#     "gene_or_protein": null,
#     "mechanism": "Antiviral clinical trial design",
#     "mutations": null,
#     "evidence_strength": null,
#     "date": null
#   },
#   {
#  ...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0f31aab2-1049-481c-95ed-40f430b80aa0
# [logging_plugin]    Author: PandemicPreventingAgent
# [logging_plugin]    Content: function_response: biosurveillanceagent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['biosurveillanceagent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    System Instruction: '
# You are the Pandemic Surveillance & Molecular-Evidence Orchestrator.
#
# Your responsibilities are strictly limited to:
#     (1) Providing optional high-level surveillance context on request
#     (2) Extr...'
# [logging_plugin]    Available Tools: ['newssurveillanceagent', 'biosurveillanceagent', 'fusion_pipeline']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: PandemicPreventingAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 2947, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bd0502b1-b184-49cc-b8b9-6ac6f3db5fa2
# [logging_plugin]    Author: PandemicPreventingAgent
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: PandemicPreventingAgent
# [logging_plugin]    Invocation ID: e-6cc5ce3f-60f5-4edc-9aa5-c076c8f4e967
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-6cc5ce3f-60f5-4edc-9aa5-c076c8f4e967
# [logging_plugin]    Final Agent: PandemicPreventingAgent

# %% [markdown]
# # **ADK Web UI Integration with Kaggle**
# Recommended to use Kaggle notebook for the following codes and utilization of the ADK web UI

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Setup and authentication complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )

# %%
from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")

# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")

# %%
# !adk create research-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY

# %%
# %%writefile research-agent/agent.py
#Importation of required libraries
from google.adk.agents import Agent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.genai import types
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.agents import Agent, LlmAgent
from google.adk.sessions import InMemorySessionService
from google.adk.sessions import DatabaseSessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from typing import Any, Dict, List
from google.adk.tools import load_memory, preload_memory
from google.adk.memory import InMemoryMemoryService
from google.adk.tools.agent_tool import AgentTool
import requests
import os
from kaggle_secrets import UserSecretsClient

#Configure Retry Options
#When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# Serper API Key
serper_api_key = UserSecretsClient().get_secret("SERPER.DEV_API_KEY")

# 1. RAW NEWS COLLECTION
def get_disease_outbreak_news(query: str, num_results: int = 5) -> List[Dict[str, str]]:
    """
    Fetch news from Serper.dev News API.
    This function has an ADK-safe signature: only primitive input args.
    """

    api_key = serper_api_key

    url = "https://google.serper.dev/news"
    headers = {"X-API-KEY": api_key}
    payload = {"q": query}

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print(f"News fetch failed ({response.status_code}): {response.text}")
        return []

    data = response.json()

    articles = data.get("news", [])[:num_results]

    return [
        {
            "title":   item.get("title"),
            "link":    item.get("link"),
            "snippet": item.get("snippet"),
            "source":  item.get("source"),
        }
        for item in articles
    ]

# 2. FILTERED OUTBREAK NEWS FUNCTION
def disease_outbreak_news(query: str) -> List[Dict[str, str]]:
    """
    Fetch current microbial or viral outbreak news using the Serper News API.
    Applies filtering for emerging infectious disease–related content.

    Returns:
        List[Dict[str, str]]
    """

    raw_news = get_disease_outbreak_news(query)

    outbreak_keywords = [
        "virus", "bacteria", "fungus", "fungal",
        "prion", "parasite",
        "outbreak", "cluster", "disease",
        "epidemic", "pandemic",
        "infection", "infectious", "news",
        "pathogen", "case count",
    ]

    filtered = []
    for item in raw_news:
        text = f"{item['title']} {item['snippet']}".lower()

        if any(keyword in text for keyword in outbreak_keywords):
            filtered.append(item)

    return filtered

# NCBI API Key
NCBI_api_key = UserSecretsClient().get_secret("NCBI_API_KEY")

#1. RESEARCH PAPERS COLLECTION AND FILTERING
def get_pubmed_papers(query: str, max_results: int = 20) -> List[Dict[str, Any]]:
    """
    Fetch research papers from PubMed.
    Applies filtering for infectious disease–related content.
    """

    api_key = NCBI_api_key

    search_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    search_params = {
        "db": "pubmed",
        "term": query,
        "retmax": max_results,
        "api_key": api_key,
        "retmode": "json"
    }

    search_response = requests.get(search_url, params=search_params)
    ids = search_response.json().get("esearchresult", {}).get("idlist", [])
    if not ids:
        return []

    fetch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    fetch_params = {
        "db": "pubmed",
        "id": ",".join(ids),
        "retmode": "xml",
        "api_key": api_key
    }
    fetch_response = requests.get(fetch_url, params=fetch_params)

    from bs4 import BeautifulSoup
    soup = BeautifulSoup(fetch_response.text, "xml")

    papers = []
    for article in soup.find_all("PubmedArticle"):
        title = article.ArticleTitle.text if article.ArticleTitle else None
        abstract = (
            article.Abstract.AbstractText.text
            if article.Abstract and article.Abstract.AbstractText
            else None
        )
        journal = (
            article.Journal.Title.text
            if article.Journal and article.Journal.Title
            else None
        )

        authors = []
        for author in article.find_all("Author"):
            first = author.ForeName.text if author.ForeName else ""
            last = author.LastName.text if author.LastName else ""
            if first or last:
                authors.append(f"{first} {last}")

        doi_tag = article.find("ArticleId", {"IdType": "doi"})
        doi = doi_tag.text if doi_tag else None

        papers.append(
            {
                "doi": doi,
                "title": title,
                "abstract": abstract,
                "journal": journal,
                "authors": authors,
            }
        )
    return papers

news_surveillance_agent = LlmAgent(
    name="newssurveillanceagent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the **NEWS Surveillance Analyzer (SP)**.
Your only job is to generate a short, data-driven Surveillance Report using the 'disease_outbreak_news' tool.

---

# OUTPUT FORMAT (MANDATORY — NO EXCEPTIONS)

### 1. Threat Assessment
State the current risk level (LOW / MODERATE / HIGH) and give one short justification.

### 2. Epidemic Trends
Summarize key indicators such as trend direction.
Do not invent values not present in the data.

### 3. Geographic Distribution
List the relevant hotspots or monitored regions based strictly on the provided data.

### 4. References
"references": [
       {
          "title": "...",
          "link": "...",
          "source": "..."
       }
  ]

---

# RULES
- Do not invent data.
- Include ALL article links from the tool output in "references".
- Use ONLY the simulated data given in the prompt.
- Do NOT add, guess, or extrapolate new statistics.
- No external assumptions.
- Keep the report concise, factual, and neutral.

""",

    tools=[disease_outbreak_news, get_disease_outbreak_news]
)

#A. RESEARCH PAPER FINDER
research_paper_finder_agent = LlmAgent(
    name="paperingestion",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config),
    instruction="""
        You are a research paper ingestion agent.
        Use the fetch_pubmed_papers tool whenever the user requests:
        - research papers
        - PubMed articles
        - biomedical literature
        - research work
        - recent research
        Return structured metadata (DOI, title, authors, abstract, journal).
        If full text is requested, explain whether full text is available via PubMed or must be accessed externally.
    """,
    tools=[fetch_pubmed_papers],
    output_key="paper_metadata"
)

#B. RESEARCH EXTRACTOR
research_extractor_agent = LlmAgent(
    name="researchextractor",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config),
    instruction="""
    Using the output of 'paper_metadata'
    Extract structured fields:
    - DOI
    - pathogen
    - variant
    - virulence_factor
    - gene_or_protein
    - mechanism
    - mutations
    - evidence_strength
    - date
    Format output as JSON list.

    # OUTPUT FORMAT (MANDATORY — NO EXCEPTIONS)
[
  {
    "doi": "...",
    "pathogen": "...",
    "variant": "...",
    "virulence_factor": "...",
    "gene_or_protein": "...",
    "mechanism": "...",
    "mutations": "...",
    "evidence_strength": "...",
    "date": "...",
    "reference": {
         "doi": "..."
    }
  }
]

• Ensure the DOI is always included inside "reference".
    """,
)

#C. BIOSURVEILLANCE
bio_surveillance_agent = SequentialAgent(
    name="biosurveillanceagent",
    sub_agents=[
        research_paper_finder_agent,
        research_extractor_agent,
    ]
)

# AGGREGATION OF THE NEWS AND RESEARCH OUTPUTS
data_aggregator_agent = LlmAgent(
    name="dataaggregatoragent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the Fusion Intelligence Agent.

You will receive:
- news_surveillance_output
- bio_surveillance_output

Your job is to integrate these into a unified analytic snapshot.

────────────────────────────────────────
FUSION TASKS (MANDATORY)
────────────────────────────────────────
1. Aggregate both inputs into a single, concise summary:
    • Key pathogen(s)
    • Relevant mutations or molecular signals
    • Outbreak regions or clusters
    • CRITICAL: Any apparent correlation between surveillance and research literatures

2. Apply the RISK ENGINE (rules below).

────────────────────────────────────────
RISK ENGINE RULES
────────────────────────────────────────
Assign a HIGH / MODERATE / LOW risk score:

- HIGH if:
    • surveillance mentions "rapid spread", "cluster expansion", or
    • molecular evidence includes "increased transmissibility",
      "immune escape", or "high-impact mutation".

- MODERATE if:
    • surveillance reports emerging but contained outbreaks OR
    • literature indicates mutations of uncertain significance.

- LOW if:
    • minimal surveillance signals AND
    • no concerning molecular factors.

────────────────────────────────────────
FUSION REQUIREMENTS
────────────────────────────────────────
1. Create a single concise analytic summary.
2. Apply the Risk Engine.
3. Aggregate ALL references:
    • News article links from surveillance
    • DOIs from molecular papers

────────────────────────────────────────
OUTPUT FORMAT (STRICT)
────────────────────────────────────────
{
  "fusion_summary": "...",
  "risk_level": "HIGH | MODERATE | LOW",
  "justification": "...",
  "references": {
        "news_articles": [
             {"title": "...", "link": "...", "source": "..."}
        ],
        "research_articles": [
             {"doi": "..."}
        ]
  }
}

────────────────────────────────────────
RULES:
• Do not fabricate references.
• Only use references passed by prior agents.
• Keep the summary concise.
""",
)

#THE FUSION PIPELINE
fusion_pipeline = SequentialAgent(
    name="fusion_pipeline",
    sub_agents=[
        news_surveillance_agent,      # existing surveillance agent
        bio_surveillance_agent,    # existing molecular evidence pipeline
        data_aggregator_agent                 # NEW fusion layer
    ]
)

# THE MAIN ORCHESTRATOR: THE CHATBOT
root_agent = LlmAgent(
    name="InteractingAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),

    instruction="""
You are the Pandemic Surveillance & Molecular-Evidence Orchestrator.

Your responsibilities are strictly limited to:
    (1) Providing optional high-level surveillance context on request
    (2) Extracting molecular evidence from scientific literature

────────────────────────────────────────────
SURVEILLANCE REQUEST ROUTING
────────────────────────────────────────────
If the user explicitly asks for:
    • surveillance
    • outbreak signals
    • global monitoring
    • epidemic situation
    • risk level
    • current news
    • latest information

Then you MUST immediately call the tool:
    news_surveillance_agent
and pass the entire user query as the input.

────────────────────────────────────────────
MOLECULAR-EVIDENCE ROUTING
────────────────────────────────────────────
If the user message contains ANY of the following words:
    virulence, virulence factor, mutation, variant,
    gene, protein, genomic, molecular, mechanism,
    sequence, strain, evidence, research,

Then you MUST immediately call the tool:
    bio_surveillance_agent
and pass the entire user query as the input.

────────────────────────────────────────────
FUSION ROUTING
────────────────────────────────────────────
If the user requests BOTH:
    • surveillance context
AND
    • molecular evidence

Then call the tool:
    fusion_pipeline

────────────────────────────────────────────
OUT OF SCOPE
────────────────────────────────────────────
If the query does not involve:
    • surveillance/outbreak context OR
    • molecular evidence

Respond ONLY with:

    "Hello! I am your research assistant and I can assist with surveillance reports and molecular-evidence analysis of emerging or known diseases."

────────────────────────────────────────────
SAFETY
────────────────────────────────────────────
Never give wet-lab steps, genetic engineering instructions,
experimental workflows, or anything operational.
Only high-level summaries of published literature or simulated data.
""",

    tools=[
        AgentTool(agent=news_surveillance_agent),
        AgentTool(agent=bio_surveillance_agent),
        AgentTool(agent=fusion_pipeline)
    ]
)

# %%
url_prefix = get_adk_proxy_url()

# %%
# !adk web --log_level DEBUG --url_prefix {url_prefix}

# %% [markdown]
# ### **Features Summary**
# **1.	Custom Tools:**
# - `get_disease_outbreak_news`: Retrieves news articles related to a given query using the *Serper.dev News API*. This function returns a list of simplified article dictionaries containing each item’s title, link, snippet, and source.
# - `disease_outbreak_news`: Retrieves news articles related to infectious diseases by first calling get_disease_outbreak_news(query) and then filtering the results. This function returns a filtered list of outbreak-relevant news items, ensuring the output focuses strictly on microbial or viral disease events.
# - `fetch_pubmed_papers`: Retrieves research papers from PubMed. Uses the retrieved IDs to fetch detailed paper data from PubMed. Uses BeautifulSoup to extract key information from each paper, and compiles all extracted data into a list of dictionaries and returns it. This function is designed for infectious disease research queries, producing structured, citation-ready outputs from PubMed.
#
# **2. LLM & Sequential Multi-Agent Systems:** *All the agents are powered by the Gemini 2.5 Flash Lite model.*
# - `news_surveillance_agent`: It generates concise surveillance reports using only the data provided by two tools: `disease_outbreak_news`  and `get_disease_outbreak_news`.
# - `research_paper_finder_agent`: Its primary role is to retrieve and structure biomedical research papers from PubMed via the `fetch_pubmed_papers` tool. It returns structured metadata for each paper, including DOI, title, authors, abstract, and journal and stores outputs under the output key: 'paper_metadata'.
# - `research_extractor_agent`: Its role is to process the output from 'paper_metadata' and extract structured, domain-specific information from each paper. The output is formatted as a JSON list, with each entry including a reference object containing the DOI.
# - `bio_surveillance_agent`: A SequentialAgent that orchestrates multiple sub-agents for bio-surveillance tasks. It sequentially runs:
# `research_paper_finder_agent` followed by `research_extractor_agent`. This setup creates a streamlined pipeline for automated collection and extraction of infectious disease research data.
# - `data_aggregator_agent`: It integrates outputs from news surveillance and bio-surveillance research. This agent serves as the final fusion layer, producing an integrated, actionable bio-surveillance.
# - `fusion_pipeline`: A SequentialAgent that orchestrates a complete bio-surveillance workflow by running three sub-agents in sequence: `news_surveillance_agent` -> `bio_surveillance_agent` -> `data_aggregator_agent`.
# - `root_agent`: Main orchestrator ChatBot for pandemic surveillance and molecular-evidence analysis.
#
# **3. Session & State Management (Short-Term Memory):** This code sets up session-based interaction with the root_agent and defines a helper function, run_session, for managing user queries. This setup enables stateful, follow-up conversations with the orchestrator agent while preserving session context.
#
# **4. Observability:** This code sets up an InMemoryRunner to interact with the `root_agent` and demonstrates a query execution with observability and enables real-time query testing with built-in logging and observability for all agent interactions.

# %% [markdown]
# # **Limitations and Future Improvements**
#
# **1. Memory (Long Term Memory) Addition:** The system lacks persistent memory, limiting continuity across interactions. Integrating scalable memory would enhance contextual understanding.
#
# **2. Enhancing Context Engineering:** Sometime queries expose gaps in adaptive response, indicating the need for improved context-handling.
#
# **3. Agent Evaluation Incorporation:** A comprehensive evaluation framework to ensure reliability and consistent agent performance across diverse scenarios.
